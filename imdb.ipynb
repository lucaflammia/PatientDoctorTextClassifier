# %%
# !pip install transformers datasets evaluate accelerate
#!pip install intel_extension_for_pytorch==2.2.0 -f https://developer.intel.com/ipex-whl-stable-cpu
# Out:
# Requirement already satisfied: transformers in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (4.37.2)
# Requirement already satisfied: datasets in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (2.16.1)
# Requirement already satisfied: evaluate in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (0.4.1)
# Requirement already satisfied: accelerate in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (0.21.0)
# Requirement already satisfied: filelock in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /home/luca/.local/lib/python3.10/site-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /home/luca/.local/lib/python3.10/site-packages (from transformers) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /home/luca/.local/lib/python3.10/site-packages (from transformers) (2.28.2)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (from transformers) (0.15.1)
# Requirement already satisfied: safetensors>=0.4.1 in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /home/luca/.local/lib/python3.10/site-packages (from transformers) (4.65.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (from datasets) (15.0.0)
# Requirement already satisfied: pyarrow-hotfix in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /home/luca/.local/lib/python3.10/site-packages (from datasets) (1.5.3)
# Requirement already satisfied: xxhash in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec<=2023.10.0,>=2023.1.0 in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (from fsspec[http]<=2023.10.0,>=2023.1.0->datasets) (2023.10.0)
# Requirement already satisfied: aiohttp in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (from datasets) (3.9.3)
# Requirement already satisfied: responses<0.19 in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (from evaluate) (0.18.0)
# Requirement already satisfied: psutil in /home/luca/.local/lib/python3.10/site-packages (from accelerate) (5.9.4)
# Requirement already satisfied: torch>=1.10.0 in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (from accelerate) (2.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/luca/.local/lib/python3.10/site-packages (from aiohttp->datasets) (22.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/luca/.local/lib/python3.10/site-packages (from requests->transformers) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (from requests->transformers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: sympy in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /home/luca/.local/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate) (12.3.101)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/luca/.local/lib/python3.10/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/luca/.local/lib/python3.10/site-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)

# %%
from datasets import load_dataset

imdb = load_dataset("imdb")
# from datasets import load_dataset

# dataset = load_dataset("LukeGPT88/text-classification-dataset")

# %% [markdown]
# ## Data Analysis

# %%
# import pandas as pd

# imdb.set_format(type="pandas")
# df = imdb["train"][:]
# df.info()

# %%
# df["label"].value_counts()

# %%
# import matplotlib.pyplot as plt

# df["label"].value_counts(ascending=True).plot.bar()
# plt.title("Frequency of Classes")
# plt.show()

# %% [markdown]
# # Tokenizer

# %%
from transformers import AutoTokenizer, AlbertForTokenClassification

tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased")
# tokenizer = AutoTokenizer.from_pretrained("albert-base-v2")
# Out:
# 2024-02-14 12:46:28.242332: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-14 12:46:28.289993: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-14 12:46:28.290053: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-14 12:46:28.290104: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-14 12:46:28.298895: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-14 12:46:29.345484: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
def preprocess_function(examples):
    return tokenizer(examples["text"], truncation=True)

# %%
tokenized_imdb = imdb.map(preprocess_function, batched=True)

# %%
tokenized_imdb['test']
# Out:
# Dataset({
#     features: ['text', 'label', 'input_ids', 'attention_mask'],
#     num_rows: 25000
# })

# %%
from transformers import DataCollatorWithPadding

data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

# %%
import numpy as np
import evaluate

def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    predictions = np.argmax(predictions, axis=1)
    return accuracy.compute(predictions=predictions, references=labels)

accuracy = evaluate.load("accuracy")

# %% [markdown]
# ## Train

# %%
id2label = {0: "NEGATIVE", 1: "POSITIVE"}
label2id = {"NEGATIVE": 0, "POSITIVE": 1}

# %%
from transformers import AutoModelForSequenceClassification, TrainingArguments, Trainer

model = AutoModelForSequenceClassification.from_pretrained(
    "distilbert-base-uncased", num_labels=2, id2label=id2label, label2id=label2id
)
# Out:
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# ## Hugging Face login

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
training_args = TrainingArguments(
    output_dir="text_classification_model",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=2,
    weight_decay=0.01,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
    push_to_hub=True,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_imdb["train"],
    eval_dataset=tokenized_imdb["test"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)

trainer.train()
# Out:
# /home/luca/anaconda3/envs/kaggle/lib/python3.10/site-packages/torch/cuda/__init__.py:628: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
#   0%|          | 0/3126 [00:00<?, ?it/s]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
trainer.push_to_hub()

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

classifier = pipeline("text-classification", model="LukeGPT88/imdb_text_classifier")
classifier("I see it and it was awesome.")
# Output:
# [{'label': 'POSITIVE', 'score': 0.9958052635192871}]
# Out:
# config.json:   0%|          | 0.00/735 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# [{'label': 'POSITIVE', 'score': 0.9958052635192871}]
